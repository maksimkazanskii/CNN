# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# 2.31260061377
# 2.31260061282
# loss: 2.312601
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)



# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -3.793930 analytic: -3.793930, relative error: 1.870203e-08
# numerical: 1.771754 analytic: 1.771754, relative error: 4.278198e-08
# numerical: 1.059666 analytic: 1.059666, relative error: 1.155378e-08
# numerical: 1.054617 analytic: 1.054617, relative error: 8.167778e-10
# numerical: -0.778243 analytic: -0.778243, relative error: 3.788452e-08
# numerical: -2.768020 analytic: -2.768020, relative error: 2.318568e-08
# numerical: 0.940174 analytic: 0.940174, relative error: 7.446848e-09
# numerical: 0.216278 analytic: 0.216278, relative error: 4.681809e-09
# numerical: 2.128074 analytic: 2.128074, relative error: 1.054861e-08
# numerical: -0.613872 analytic: -0.613872, relative error: 1.387069e-08
# numerical: 0.849578 analytic: 0.849578, relative error: 4.395201e-08
# numerical: -0.890550 analytic: -0.890550, relative error: 1.102839e-08
# numerical: 1.981920 analytic: 1.981920, relative error: 1.388751e-09
# numerical: 2.194631 analytic: 2.194631, relative error: 2.229011e-09
# numerical: 0.193467 analytic: 0.193467, relative error: 1.395229e-07
# numerical: 1.010203 analytic: 1.010203, relative error: 5.353158e-08
# numerical: -0.367205 analytic: -0.367205, relative error: 1.623735e-07
# numerical: -2.111030 analytic: -2.111030, relative error: 8.741677e-09
# numerical: -0.207106 analytic: -0.207106, relative error: 8.246667e-08
# numerical: 2.336667 analytic: 2.336667, relative error: 1.645744e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.312601e+00 computed in 0.011350s
# vectorized loss: 2.312601e+00 computed in 0.011259s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [1e3,5e3,1e4,5e4, 1e8,5e8]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

for rate in learning_rates:
    for reg in regularization_strengths:

        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=rate, reg=reg,
                      num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        training_accuracy=(np.mean(y_train == y_train_pred))
        y_val_pred = softmax.predict(X_val)
        validation_accuracy=(np.mean(y_val == y_val_pred))
        results[(rate,reg)]=(training_accuracy,validation_accuracy)
        print("Learning Rate",rate,"Regularization",reg,"T_accuracy:",training_accuracy,"V_accuracy:", validation_accuracy)
        if (validation_accuracy>best_val):
            best_softmax=softmax
            best_val=validation_accuracy
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 1500: loss 20.414809
# iteration 100 / 1500: loss 18.813481
# iteration 200 / 1500: loss 18.259457
# iteration 300 / 1500: loss 17.725336
# iteration 400 / 1500: loss 17.119118
# iteration 500 / 1500: loss 16.769686
# iteration 600 / 1500: loss 16.307279
# iteration 700 / 1500: loss 15.916373
# iteration 800 / 1500: loss 15.792165
# iteration 900 / 1500: loss 15.444558
# iteration 1000 / 1500: loss 14.767807
# iteration 1100 / 1500: loss 14.504410
# iteration 1200 / 1500: loss 14.245192
# iteration 1300 / 1500: loss 13.910895
# iteration 1400 / 1500: loss 13.812194
# ('Learning Rate', 1e-07, 'Regularization', 1000.0, 'T_accuracy:', 0.25889795918367348, 'V_accuracy:', 0.26300000000000001)
# iteration 0 / 1500: loss 81.128929
# iteration 100 / 1500: loss 72.293599
# iteration 200 / 1500: loss 65.141842
# iteration 300 / 1500: loss 59.148000
# iteration 400 / 1500: loss 53.478298
# iteration 500 / 1500: loss 48.283387
# iteration 600 / 1500: loss 43.715704
# iteration 700 / 1500: loss 39.522437
# iteration 800 / 1500: loss 36.123128
# iteration 900 / 1500: loss 32.766002
# iteration 1000 / 1500: loss 29.672085
# iteration 1100 / 1500: loss 27.204114
# iteration 1200 / 1500: loss 24.413264
# iteration 1300 / 1500: loss 22.381508
# iteration 1400 / 1500: loss 20.340793
# ('Learning Rate', 1e-07, 'Regularization', 5000.0, 'T_accuracy:', 0.28946938775510206, 'V_accuracy:', 0.29099999999999998)
# iteration 0 / 1500: loss 159.759482
# iteration 100 / 1500: loss 130.059260
# iteration 200 / 1500: loss 106.397289
# iteration 300 / 1500: loss 87.234327
# iteration 400 / 1500: loss 71.640756
# iteration 500 / 1500: loss 58.869559
# iteration 600 / 1500: loss 48.296941
# iteration 700 / 1500: loss 39.848308
# iteration 800 / 1500: loss 32.935441
# iteration 900 / 1500: loss 27.286399
# iteration 1000 / 1500: loss 22.681593
# iteration 1100 / 1500: loss 18.917772
# iteration 1200 / 1500: loss 15.769723
# iteration 1300 / 1500: loss 13.408215
# iteration 1400 / 1500: loss 11.256689
# ('Learning Rate', 1e-07, 'Regularization', 10000.0, 'T_accuracy:', 0.33183673469387753, 'V_accuracy:', 0.34300000000000003)
# iteration 0 / 1500: loss 773.525394
# iteration 100 / 1500: loss 283.670922
# iteration 200 / 1500: loss 105.120651
# iteration 300 / 1500: loss 39.721669
# iteration 400 / 1500: loss 15.878912
# iteration 500 / 1500: loss 7.148172
# iteration 600 / 1500: loss 3.936282
# iteration 700 / 1500: loss 2.805166
# iteration 800 / 1500: loss 2.342454
# iteration 900 / 1500: loss 2.167357
# iteration 1000 / 1500: loss 2.145441
# iteration 1100 / 1500: loss 2.088773
# iteration 1200 / 1500: loss 2.091413
# iteration 1300 / 1500: loss 2.085849
# iteration 1400 / 1500: loss 2.151559
# ('Learning Rate', 1e-07, 'Regularization', 50000.0, 'T_accuracy:', 0.33116326530612245, 'V_accuracy:', 0.34899999999999998)
# iteration 0 / 1500: loss 1525213.382810
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# ('Learning Rate', 1e-07, 'Regularization', 100000000.0, 'T_accuracy:', 0.10026530612244898, 'V_accuracy:', 0.086999999999999994)
# iteration 0 / 1500: loss 7697026.017061
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# ('Learning Rate', 1e-07, 'Regularization', 500000000.0, 'T_accuracy:', 0.10026530612244898, 'V_accuracy:', 0.086999999999999994)
# iteration 0 / 1500: loss 20.653772
# iteration 100 / 1500: loss 16.666338
# iteration 200 / 1500: loss 14.789142
# iteration 300 / 1500: loss 13.474235
# iteration 400 / 1500: loss 12.349004
# iteration 500 / 1500: loss 11.314662
# iteration 600 / 1500: loss 10.228352
# iteration 700 / 1500: loss 9.543596
# iteration 800 / 1500: loss 8.528307
# iteration 900 / 1500: loss 7.904826
# iteration 1000 / 1500: loss 7.449682
# iteration 1100 / 1500: loss 6.962675
# iteration 1200 / 1500: loss 6.349670
# iteration 1300 / 1500: loss 5.812029
# iteration 1400 / 1500: loss 5.511069
# ('Learning Rate', 5e-07, 'Regularization', 1000.0, 'T_accuracy:', 0.36473469387755103, 'V_accuracy:', 0.372)
# iteration 0 / 1500: loss 83.351279
# iteration 100 / 1500: loss 49.048323
# iteration 200 / 1500: loss 29.976457
# iteration 300 / 1500: loss 18.804673
# iteration 400 / 1500: loss 12.184048
# iteration 500 / 1500: loss 8.017205
# iteration 600 / 1500: loss 5.630005
# iteration 700 / 1500: loss 4.151951
# iteration 800 / 1500: loss 3.294572
# iteration 900 / 1500: loss 2.737285
# iteration 1000 / 1500: loss 2.458743
# iteration 1100 / 1500: loss 2.220186
# iteration 1200 / 1500: loss 2.136996
# iteration 1300 / 1500: loss 2.020557
# iteration 1400 / 1500: loss 1.979481
# ('Learning Rate', 5e-07, 'Regularization', 5000.0, 'T_accuracy:', 0.38816326530612244, 'V_accuracy:', 0.40200000000000002)
# iteration 0 / 1500: loss 160.770902
# iteration 100 / 1500: loss 58.747704
# iteration 200 / 1500: loss 22.503861
# iteration 300 / 1500: loss 9.430712
# iteration 400 / 1500: loss 4.672424
# iteration 500 / 1500: loss 2.976715
# iteration 600 / 1500: loss 2.386595
# iteration 700 / 1500: loss 2.124719
# iteration 800 / 1500: loss 2.018434
# iteration 900 / 1500: loss 2.010111
# iteration 1000 / 1500: loss 1.951055
# iteration 1100 / 1500: loss 1.941639
# iteration 1200 / 1500: loss 1.954280
# iteration 1300 / 1500: loss 1.892349
# iteration 1400 / 1500: loss 1.933509
# ('Learning Rate', 5e-07, 'Regularization', 10000.0, 'T_accuracy:', 0.37122448979591838, 'V_accuracy:', 0.39300000000000002)
# iteration 0 / 1500: loss 769.881301
# iteration 100 / 1500: loss 6.901493
# iteration 200 / 1500: loss 2.115270
# iteration 300 / 1500: loss 2.146296
# iteration 400 / 1500: loss 2.149046
# iteration 500 / 1500: loss 2.031023
# iteration 600 / 1500: loss 2.092588
# iteration 700 / 1500: loss 2.125930
# iteration 800 / 1500: loss 2.063289
# iteration 900 / 1500: loss 2.144237
# iteration 1000 / 1500: loss 2.095043
# iteration 1100 / 1500: loss 2.102125
# iteration 1200 / 1500: loss 2.157760
# iteration 1300 / 1500: loss 2.082854
# iteration 1400 / 1500: loss 2.061759
# ('Learning Rate', 5e-07, 'Regularization', 50000.0, 'T_accuracy:', 0.31987755102040816, 'V_accuracy:', 0.33800000000000002)
# iteration 0 / 1500: loss 1515901.339515
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# ('Learning Rate', 5e-07, 'Regularization', 100000000.0, 'T_accuracy:', 0.10026530612244898, 'V_accuracy:', 0.086999999999999994)
# iteration 0 / 1500: loss 7695871.074515
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# ('Learning Rate', 5e-07, 'Regularization', 500000000.0, 'T_accuracy:', 0.10026530612244898, 'V_accuracy:', 0.086999999999999994)
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.258898 val accuracy: 0.263000
# lr 1.000000e-07 reg 5.000000e+03 train accuracy: 0.289469 val accuracy: 0.291000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.331837 val accuracy: 0.343000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.331163 val accuracy: 0.349000
# lr 1.000000e-07 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-07 reg 5.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.364735 val accuracy: 0.372000
# lr 5.000000e-07 reg 5.000000e+03 train accuracy: 0.388163 val accuracy: 0.402000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.371224 val accuracy: 0.393000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.319878 val accuracy: 0.338000
# lr 5.000000e-07 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-07 reg 5.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.402000
# cs231n/classifiers/softmax.py:33: RuntimeWarning: overflow encountered in exp
#   denom=np.sum(exp_matrix,axis=1)+1e-8
# cs231n/classifiers/softmax.py:55: RuntimeWarning: invalid value encountered in divide
#   dW = np.dot(dW, X.T)

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.374000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])

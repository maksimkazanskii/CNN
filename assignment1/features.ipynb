# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [ 5e-9]
regularization_strengths = [1e5,5.0*10e5, 1e6,5.0*10e6, 1e7]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################

for rate in learning_rates:
    for reg in regularization_strengths:

        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=rate, reg=reg,
                      num_iters=10000, verbose=True)
        y_train_pred = svm.predict(X_train_feats)
        training_accuracy=(np.mean(y_train == y_train_pred))
        y_val_pred = svm.predict(X_val_feats)
        validation_accuracy=(np.mean(y_val == y_val_pred))
        results[(rate,reg)]=(training_accuracy,validation_accuracy)
        print("Learning Rate",rate,"Regularization",reg,"T_accuracy:",training_accuracy,"V_accuracy:", validation_accuracy)
        if (validation_accuracy>best_val):
            best_svm=svm
            best_val=validation_accuracy
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 10000: loss 83.992680
# iteration 100 / 10000: loss 76.840451
# iteration 200 / 10000: loss 70.393250
# iteration 300 / 10000: loss 64.553093
# iteration 400 / 10000: loss 59.246054
# iteration 500 / 10000: loss 54.477291
# iteration 600 / 10000: loss 50.147023
# iteration 700 / 10000: loss 46.229992
# iteration 800 / 10000: loss 42.684370
# iteration 900 / 10000: loss 39.473305
# iteration 1000 / 10000: loss 36.575512
# iteration 1100 / 10000: loss 33.956842
# iteration 1200 / 10000: loss 31.576006
# iteration 1300 / 10000: loss 29.423449
# iteration 1400 / 10000: loss 27.482098
# iteration 1500 / 10000: loss 25.724247
# iteration 1600 / 10000: loss 24.132151
# iteration 1700 / 10000: loss 22.691292
# iteration 1800 / 10000: loss 21.387213
# iteration 1900 / 10000: loss 20.213832
# iteration 2000 / 10000: loss 19.138537
# iteration 2100 / 10000: loss 18.171136
# iteration 2200 / 10000: loss 17.301307
# iteration 2300 / 10000: loss 16.512462
# iteration 2400 / 10000: loss 15.797308
# iteration 2500 / 10000: loss 15.153788
# iteration 2600 / 10000: loss 14.566230
# iteration 2700 / 10000: loss 14.034347
# iteration 2800 / 10000: loss 13.554048
# iteration 2900 / 10000: loss 13.125495
# iteration 3000 / 10000: loss 12.732914
# iteration 3100 / 10000: loss 12.374061
# iteration 3200 / 10000: loss 12.054400
# iteration 3300 / 10000: loss 11.765239
# iteration 3400 / 10000: loss 11.501228
# iteration 3500 / 10000: loss 11.262535
# iteration 3600 / 10000: loss 11.044114
# iteration 3700 / 10000: loss 10.854165
# iteration 3800 / 10000: loss 10.677387
# iteration 3900 / 10000: loss 10.515687
# iteration 4000 / 10000: loss 10.369492
# iteration 4100 / 10000: loss 10.240866
# iteration 4200 / 10000: loss 10.121105
# iteration 4300 / 10000: loss 10.014798
# iteration 4400 / 10000: loss 9.919522
# iteration 4500 / 10000: loss 9.830682
# iteration 4600 / 10000: loss 9.753475
# iteration 4700 / 10000: loss 9.680810
# iteration 4800 / 10000: loss 9.617231
# iteration 4900 / 10000: loss 9.556702
# iteration 5000 / 10000: loss 9.503438
# iteration 5100 / 10000: loss 9.455581
# iteration 5200 / 10000: loss 9.413093
# iteration 5300 / 10000: loss 9.372972
# iteration 5400 / 10000: loss 9.338584
# iteration 5500 / 10000: loss 9.305734
# iteration 5600 / 10000: loss 9.276376
# iteration 5700 / 10000: loss 9.250467
# iteration 5800 / 10000: loss 9.225941
# iteration 5900 / 10000: loss 9.204598
# iteration 6000 / 10000: loss 9.185979
# iteration 6100 / 10000: loss 9.167420
# iteration 6200 / 10000: loss 9.152034
# iteration 6300 / 10000: loss 9.137235
# iteration 6400 / 10000: loss 9.123458
# iteration 6500 / 10000: loss 9.112328
# iteration 6600 / 10000: loss 9.101649
# iteration 6700 / 10000: loss 9.091959
# iteration 6800 / 10000: loss 9.082883
# iteration 6900 / 10000: loss 9.074944
# iteration 7000 / 10000: loss 9.067975
# iteration 7100 / 10000: loss 9.061823
# iteration 7200 / 10000: loss 9.055640
# iteration 7300 / 10000: loss 9.050355
# iteration 7400 / 10000: loss 9.045134
# iteration 7500 / 10000: loss 9.041407
# iteration 7600 / 10000: loss 9.036916
# iteration 7700 / 10000: loss 9.033590
# iteration 7800 / 10000: loss 9.030129
# iteration 7900 / 10000: loss 9.027281
# iteration 8000 / 10000: loss 9.024547
# iteration 8100 / 10000: loss 9.022484
# iteration 8200 / 10000: loss 9.020123
# iteration 8300 / 10000: loss 9.018338
# iteration 8400 / 10000: loss 9.016671
# iteration 8500 / 10000: loss 9.014594
# iteration 8600 / 10000: loss 9.013541
# iteration 8700 / 10000: loss 9.012007
# iteration 8800 / 10000: loss 9.010924
# iteration 8900 / 10000: loss 9.009819
# iteration 9000 / 10000: loss 9.009054
# iteration 9100 / 10000: loss 9.008038
# iteration 9200 / 10000: loss 9.007304
# iteration 9300 / 10000: loss 9.006423
# iteration 9400 / 10000: loss 9.005810
# iteration 9500 / 10000: loss 9.005209
# iteration 9600 / 10000: loss 9.004725
# iteration 9700 / 10000: loss 9.004343
# iteration 9800 / 10000: loss 9.003812
# iteration 9900 / 10000: loss 9.003364
# ('Learning Rate', 5e-09, 'Regularization', 100000.0, 'T_accuracy:', 0.24459183673469387, 'V_accuracy:', 0.23899999999999999)
# iteration 0 / 10000: loss 4062.792403
# iteration 100 / 10000: loss 34.632029
# iteration 200 / 10000: loss 9.162146
# iteration 300 / 10000: loss 9.001010
# iteration 400 / 10000: loss 8.999998
# iteration 500 / 10000: loss 8.999992
# iteration 600 / 10000: loss 8.999994
# iteration 700 / 10000: loss 8.999993
# iteration 800 / 10000: loss 8.999995
# iteration 900 / 10000: loss 8.999992
# iteration 1000 / 10000: loss 8.999992
# iteration 1100 / 10000: loss 8.999994
# iteration 1200 / 10000: loss 8.999991
# iteration 1300 / 10000: loss 8.999994
# iteration 1400 / 10000: loss 8.999993
# iteration 1500 / 10000: loss 8.999995
# iteration 1600 / 10000: loss 8.999995
# iteration 1700 / 10000: loss 8.999995
# iteration 1800 / 10000: loss 8.999993
# iteration 1900 / 10000: loss 8.999993
# iteration 2000 / 10000: loss 8.999992
# iteration 2100 / 10000: loss 8.999994
# iteration 2200 / 10000: loss 8.999993
# iteration 2300 / 10000: loss 8.999994
# iteration 2400 / 10000: loss 8.999992
# iteration 2500 / 10000: loss 8.999994
# iteration 2600 / 10000: loss 8.999993
# iteration 2700 / 10000: loss 8.999993
# iteration 2800 / 10000: loss 8.999993
# iteration 2900 / 10000: loss 8.999993
# iteration 3000 / 10000: loss 8.999993
# iteration 3100 / 10000: loss 8.999992
# iteration 3200 / 10000: loss 8.999993
# iteration 3300 / 10000: loss 8.999992
# iteration 3400 / 10000: loss 8.999993
# iteration 3500 / 10000: loss 8.999993
# iteration 3600 / 10000: loss 8.999994
# iteration 3700 / 10000: loss 8.999993
# iteration 3800 / 10000: loss 8.999992
# iteration 3900 / 10000: loss 8.999995
# iteration 4000 / 10000: loss 8.999993
# iteration 4100 / 10000: loss 8.999993
# iteration 4200 / 10000: loss 8.999992
# iteration 4300 / 10000: loss 8.999994
# iteration 4400 / 10000: loss 8.999995
# iteration 4500 / 10000: loss 8.999994
# iteration 4600 / 10000: loss 8.999994
# iteration 4700 / 10000: loss 8.999993
# iteration 4800 / 10000: loss 8.999993
# iteration 4900 / 10000: loss 8.999993
# iteration 5000 / 10000: loss 8.999992
# iteration 5100 / 10000: loss 8.999993
# iteration 5200 / 10000: loss 8.999994
# iteration 5300 / 10000: loss 8.999995
# iteration 5400 / 10000: loss 8.999994
# iteration 5500 / 10000: loss 8.999994
# iteration 5600 / 10000: loss 8.999993
# iteration 5700 / 10000: loss 8.999992
# iteration 5800 / 10000: loss 8.999992
# iteration 5900 / 10000: loss 8.999993
# iteration 6000 / 10000: loss 8.999992
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-de80ef60d7f6> in <module>()
#      24         svm = LinearSVM()
#      25         loss_hist = svm.train(X_train_feats, y_train, learning_rate=rate, reg=reg,
# ---> 26                       num_iters=10000, verbose=True)
#      27         y_train_pred = svm.predict(X_train_feats)
#      28         training_accuracy=(np.mean(y_train == y_train_pred))
#
# /home/andrey/Desktop/CNN/assignment1/cs231n/classifiers/linear_classifier.pyc in train(self, X, y, learning_rate, reg, num_iters, batch_size, verbose)
#      51         # replacement is faster than sampling without replacement.              #
#      52         #########################################################################
# ---> 53         random_indexes=np.random.choice(num_train,batch_size)
#      54         X_batch=X[random_indexes,:]
#      55         y_batch=y[random_indexes]
#
# KeyboardInterrupt:

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.417

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

learning_rates = [5.0*1e-4]
regularization_strengths = [0.8,1.0,2.0,10.0]
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
for rate in learning_rates:
    for reg in regularization_strengths:

        input_size = input_dim
        hidden_size = hidden_dim
        num_classes = num_classes
        
        net = TwoLayerNet(input_size, hidden_size, num_classes)
        
        stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=20000, batch_size=200,
            learning_rate=rate, learning_rate_decay=0.85,
            reg=reg, verbose=True)
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        train_acc=(net.predict(X_train_feats) == y_train).mean()
        print 'Validation accuracy: ', val_acc, 'Learning rate' , rate,'regularization',reg
        results[(reg,rate)]=(train_acc,val_acc)
        if (val_acc>best_val):
            best_net=net
            best_val=val_acc
            
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 20000: loss 2.302916
# iteration 100 / 20000: loss 2.302915
# iteration 200 / 20000: loss 2.447887
# iteration 300 / 20000: loss 3.886660
# iteration 400 / 20000: loss 5.618441
# iteration 500 / 20000: loss 7.417955
# iteration 600 / 20000: loss 8.790568
# iteration 700 / 20000: loss 9.878417
# iteration 800 / 20000: loss 10.593812
# iteration 900 / 20000: loss 11.448293
# iteration 1000 / 20000: loss 12.026071
# iteration 1100 / 20000: loss 12.233752
# iteration 1200 / 20000: loss 12.847654
# iteration 1300 / 20000: loss 13.428942
# iteration 1400 / 20000: loss 13.752176
# iteration 1500 / 20000: loss 14.141666
# iteration 1600 / 20000: loss 14.556697
# iteration 1700 / 20000: loss 14.781960
# iteration 1800 / 20000: loss 15.275338
# iteration 1900 / 20000: loss 15.554381
# iteration 2000 / 20000: loss 15.879739
# iteration 2100 / 20000: loss 16.163996
# iteration 2200 / 20000: loss 16.446995
# iteration 2300 / 20000: loss 16.701520
# iteration 2400 / 20000: loss 17.051222
# iteration 2500 / 20000: loss 17.397209
# iteration 2600 / 20000: loss 17.425943
# iteration 2700 / 20000: loss 17.653846
# iteration 2800 / 20000: loss 17.852459
# iteration 2900 / 20000: loss 18.102655
# iteration 3000 / 20000: loss 18.350967
# iteration 3100 / 20000: loss 18.477795
# iteration 3200 / 20000: loss 18.661539
# iteration 3300 / 20000: loss 18.900240
# iteration 3400 / 20000: loss 19.022080
# iteration 3500 / 20000: loss 19.022630
# iteration 3600 / 20000: loss 19.296662
# iteration 3700 / 20000: loss 19.456420
# iteration 3800 / 20000: loss 19.559167
# iteration 3900 / 20000: loss 19.660559
# iteration 4000 / 20000: loss 19.854087
# iteration 4100 / 20000: loss 19.959258
# iteration 4200 / 20000: loss 19.925169
# iteration 4300 / 20000: loss 20.055757
# iteration 4400 / 20000: loss 20.223414
# iteration 4500 / 20000: loss 20.175776
# iteration 4600 / 20000: loss 20.286518
# iteration 4700 / 20000: loss 20.319856
# iteration 4800 / 20000: loss 20.295739
# iteration 4900 / 20000: loss 20.537738
# iteration 5000 / 20000: loss 20.582362
# iteration 5100 / 20000: loss 20.638321
# iteration 5200 / 20000: loss 20.691338
# iteration 5300 / 20000: loss 20.784329
# iteration 5400 / 20000: loss 20.808692
# iteration 5500 / 20000: loss 20.806578
# iteration 5600 / 20000: loss 20.847232
# iteration 5700 / 20000: loss 20.814794
# iteration 5800 / 20000: loss 21.020823
# iteration 5900 / 20000: loss 20.830809
# iteration 6000 / 20000: loss 21.036947
# iteration 6100 / 20000: loss 21.041969
# iteration 6200 / 20000: loss 21.092574
# iteration 6300 / 20000: loss 21.150238
# iteration 6400 / 20000: loss 21.085535
# iteration 6500 / 20000: loss 21.187008
# iteration 6600 / 20000: loss 21.190434
# iteration 6700 / 20000: loss 21.065638
# iteration 6800 / 20000: loss 21.134761
# iteration 6900 / 20000: loss 21.098486
# iteration 7000 / 20000: loss 21.316330
# iteration 7100 / 20000: loss 21.085088
# iteration 7200 / 20000: loss 21.147690
# iteration 7300 / 20000: loss 21.197334
# iteration 7400 / 20000: loss 21.281048
# iteration 7500 / 20000: loss 21.424959
# iteration 7600 / 20000: loss 21.323270
# iteration 7700 / 20000: loss 21.328284
# iteration 7800 / 20000: loss 21.427675
# iteration 7900 / 20000: loss 21.214629
# iteration 8000 / 20000: loss 21.490541
# iteration 8100 / 20000: loss 21.380033
# iteration 8200 / 20000: loss 21.403937
# iteration 8300 / 20000: loss 21.222847
# iteration 8400 / 20000: loss 21.493664
# iteration 8500 / 20000: loss 21.434472
# iteration 8600 / 20000: loss 21.380609
# iteration 8700 / 20000: loss 21.379823
# iteration 8800 / 20000: loss 21.310603
# iteration 8900 / 20000: loss 21.348170
# iteration 9000 / 20000: loss 21.383435
# iteration 9100 / 20000: loss 21.280840
# iteration 9200 / 20000: loss 21.473676
# iteration 9300 / 20000: loss 21.394309
# iteration 9400 / 20000: loss 21.456033
# iteration 9500 / 20000: loss 21.309967
# iteration 9600 / 20000: loss 21.376055
# iteration 9700 / 20000: loss 21.508142
# iteration 9800 / 20000: loss 21.498467
# iteration 9900 / 20000: loss 21.430056
# iteration 10000 / 20000: loss 21.455488
# iteration 10100 / 20000: loss 21.456238
# iteration 10200 / 20000: loss 21.338497
# iteration 10300 / 20000: loss 21.337056
# iteration 10400 / 20000: loss 21.510678
# iteration 10500 / 20000: loss 21.373786
# iteration 10600 / 20000: loss 21.501341
# iteration 10700 / 20000: loss 21.429587
# iteration 10800 / 20000: loss 21.394856
# iteration 10900 / 20000: loss 21.387984
# iteration 11000 / 20000: loss 21.392851
# iteration 11100 / 20000: loss 21.539857
# iteration 11200 / 20000: loss 21.466406
# iteration 11300 / 20000: loss 21.381929
# iteration 11400 / 20000: loss 21.456278
# iteration 11500 / 20000: loss 21.389171
# iteration 11600 / 20000: loss 21.444080
# iteration 11700 / 20000: loss 21.541173
# iteration 11800 / 20000: loss 21.492484
# iteration 11900 / 20000: loss 21.461468
# iteration 12000 / 20000: loss 21.351419
# iteration 12100 / 20000: loss 21.435875
# iteration 12200 / 20000: loss 21.617370
# iteration 12300 / 20000: loss 21.538850
# iteration 12400 / 20000: loss 21.462815
# iteration 12500 / 20000: loss 21.405435
# iteration 12600 / 20000: loss 21.476040
# iteration 12700 / 20000: loss 21.513004
# iteration 12800 / 20000: loss 21.450412
# iteration 12900 / 20000: loss 21.544272
# iteration 13000 / 20000: loss 21.428768
# iteration 13100 / 20000: loss 21.430015
# iteration 13200 / 20000: loss 21.618094
# iteration 13300 / 20000: loss 21.425517
# iteration 13400 / 20000: loss 21.458635
# iteration 13500 / 20000: loss 21.475728
# iteration 13600 / 20000: loss 21.502062
# iteration 13700 / 20000: loss 21.547013
# iteration 13800 / 20000: loss 21.456136
# iteration 13900 / 20000: loss 21.553103
# iteration 14000 / 20000: loss 21.504167
# iteration 14100 / 20000: loss 21.435867
# iteration 14200 / 20000: loss 21.589881
# iteration 14300 / 20000: loss 21.670190
# iteration 14400 / 20000: loss 21.509828
# iteration 14500 / 20000: loss 21.461957
# iteration 14600 / 20000: loss 21.384540
# iteration 14700 / 20000: loss 21.372448
# iteration 14800 / 20000: loss 21.589474
# iteration 14900 / 20000: loss 21.505491
# iteration 15000 / 20000: loss 21.372332
# iteration 15100 / 20000: loss 21.481226
# iteration 15200 / 20000: loss 21.486972
# iteration 15300 / 20000: loss 21.542084
# iteration 15400 / 20000: loss 21.411433
# iteration 15500 / 20000: loss 21.460440
# iteration 15600 / 20000: loss 21.345313
# iteration 15700 / 20000: loss 21.529273
# iteration 15800 / 20000: loss 21.422353
# iteration 15900 / 20000: loss 21.433246
# iteration 16000 / 20000: loss 21.512320
# iteration 16100 / 20000: loss 21.410463
# iteration 16200 / 20000: loss 21.607267
# iteration 16300 / 20000: loss 21.436604
# iteration 16400 / 20000: loss 21.515264
# iteration 16500 / 20000: loss 21.458625
# iteration 16600 / 20000: loss 21.392480
# iteration 16700 / 20000: loss 21.425597
# iteration 16800 / 20000: loss 21.565832
# iteration 16900 / 20000: loss 21.455943
# iteration 17000 / 20000: loss 21.532342
# iteration 17100 / 20000: loss 21.614024
# iteration 17200 / 20000: loss 21.574906
# iteration 17300 / 20000: loss 21.602027
# iteration 17400 / 20000: loss 21.452437
# iteration 17500 / 20000: loss 21.440811
# iteration 17600 / 20000: loss 21.491602
# iteration 17700 / 20000: loss 21.489353
# iteration 17800 / 20000: loss 21.385533
# iteration 17900 / 20000: loss 21.605257
# iteration 18000 / 20000: loss 21.426972
# iteration 18100 / 20000: loss 21.385895
# iteration 18200 / 20000: loss 21.621011
# iteration 18300 / 20000: loss 21.402424
# iteration 18400 / 20000: loss 21.497799
# iteration 18500 / 20000: loss 21.531524
# iteration 18600 / 20000: loss 21.366295
# iteration 18700 / 20000: loss 21.380875
# iteration 18800 / 20000: loss 21.414424
# iteration 18900 / 20000: loss 21.350291
# iteration 19000 / 20000: loss 21.488015
# iteration 19100 / 20000: loss 21.413798
# iteration 19200 / 20000: loss 21.366006
# iteration 19300 / 20000: loss 21.480924
# iteration 19400 / 20000: loss 21.556147
# iteration 19500 / 20000: loss 21.415878
# iteration 19600 / 20000: loss 21.370136
# iteration 19700 / 20000: loss 21.406699
# iteration 19800 / 20000: loss 21.416007
# iteration 19900 / 20000: loss 21.481690
# Validation accuracy:  0.533 Learning rate 0.0005 regularization 0.8
# iteration 0 / 20000: loss 2.302997
# iteration 100 / 20000: loss 2.305338
# iteration 200 / 20000: loss 2.519645
# iteration 300 / 20000: loss 4.438334
# iteration 400 / 20000: loss 6.598558
# iteration 500 / 20000: loss 8.688021
# iteration 600 / 20000: loss 10.541814
# iteration 700 / 20000: loss 11.938557
# iteration 800 / 20000: loss 13.067175
# iteration 900 / 20000: loss 13.963555
# iteration 1000 / 20000: loss 14.746068
# iteration 1100 / 20000: loss 15.470214
# iteration 1200 / 20000: loss 16.005894
# iteration 1300 / 20000: loss 16.733312
# iteration 1400 / 20000: loss 17.380594
# iteration 1500 / 20000: loss 17.969865
# iteration 1600 / 20000: loss 18.596427
# iteration 1700 / 20000: loss 19.092641
# iteration 1800 / 20000: loss 19.618227
# iteration 1900 / 20000: loss 19.911116
# iteration 2000 / 20000: loss 20.504055
# iteration 2100 / 20000: loss 20.786386
# iteration 2200 / 20000: loss 21.279895
# iteration 2300 / 20000: loss 21.729897
# iteration 2400 / 20000: loss 22.065267
# iteration 2500 / 20000: loss 22.560703
# iteration 2600 / 20000: loss 22.813104
# iteration 2700 / 20000: loss 23.335631
# iteration 2800 / 20000: loss 23.443749
# iteration 2900 / 20000: loss 23.740614
# iteration 3000 / 20000: loss 23.999351
# iteration 3100 / 20000: loss 24.278193
# iteration 3200 / 20000: loss 24.627815
# iteration 3300 / 20000: loss 24.854096
# iteration 3400 / 20000: loss 24.871724
# iteration 3500 / 20000: loss 25.180235
# iteration 3600 / 20000: loss 25.521395
# iteration 3700 / 20000: loss 25.716450
# iteration 3800 / 20000: loss 25.920995
# iteration 3900 / 20000: loss 25.826149
# iteration 4000 / 20000: loss 26.177912
# iteration 4100 / 20000: loss 26.386024
# iteration 4200 / 20000: loss 26.404980
# iteration 4300 / 20000: loss 26.622471
# iteration 4400 / 20000: loss 26.628610
# iteration 4500 / 20000: loss 26.758898
# iteration 4600 / 20000: loss 26.999502
# iteration 4700 / 20000: loss 27.097457
# iteration 4800 / 20000: loss 27.289802
# iteration 4900 / 20000: loss 27.314098
# iteration 5000 / 20000: loss 27.292814
# iteration 5100 / 20000: loss 27.550481
# iteration 5200 / 20000: loss 27.533479
# iteration 5300 / 20000: loss 27.566822
# iteration 5400 / 20000: loss 27.739128
# iteration 5500 / 20000: loss 27.707498
# iteration 5600 / 20000: loss 27.974809
# iteration 5700 / 20000: loss 27.868183
# iteration 5800 / 20000: loss 27.997328
# iteration 5900 / 20000: loss 28.063261
# iteration 6000 / 20000: loss 27.970748
# iteration 6100 / 20000: loss 28.063459
# iteration 6200 / 20000: loss 28.129312
# iteration 6300 / 20000: loss 28.068100
# iteration 6400 / 20000: loss 28.158885
# iteration 6500 / 20000: loss 28.194779
# iteration 6600 / 20000: loss 28.193781
# iteration 6700 / 20000: loss 28.293771
# iteration 6800 / 20000: loss 28.257421
# iteration 6900 / 20000: loss 28.382165
# iteration 7000 / 20000: loss 28.333562
# iteration 7100 / 20000: loss 28.432664
# iteration 7200 / 20000: loss 28.403467
# iteration 7300 / 20000: loss 28.426112
# iteration 7400 / 20000: loss 28.457960
# iteration 7500 / 20000: loss 28.635573
# iteration 7600 / 20000: loss 28.490620
# iteration 7700 / 20000: loss 28.570493
# iteration 7800 / 20000: loss 28.592337
# iteration 7900 / 20000: loss 28.456066
# iteration 8000 / 20000: loss 28.395349
# iteration 8100 / 20000: loss 28.550175
# iteration 8200 / 20000: loss 28.590788
# iteration 8300 / 20000: loss 28.549498
# iteration 8400 / 20000: loss 28.611805
# iteration 8500 / 20000: loss 28.743342
# iteration 8600 / 20000: loss 28.535714
# iteration 8700 / 20000: loss 28.622666
# iteration 8800 / 20000: loss 28.466664
# iteration 8900 / 20000: loss 28.677123
# iteration 9000 / 20000: loss 28.763643
# iteration 9100 / 20000: loss 28.673462
# iteration 9200 / 20000: loss 28.642045
# iteration 9300 / 20000: loss 28.653216
# iteration 9400 / 20000: loss 28.691537
# iteration 9500 / 20000: loss 28.724796
# iteration 9600 / 20000: loss 28.679942
# iteration 9700 / 20000: loss 28.681511
# iteration 9800 / 20000: loss 28.583327
# iteration 9900 / 20000: loss 28.497582
# iteration 10000 / 20000: loss 28.822893
# iteration 10100 / 20000: loss 28.735250
# iteration 10200 / 20000: loss 28.715759
# iteration 10300 / 20000: loss 28.669828
# iteration 10400 / 20000: loss 28.640267
# iteration 10500 / 20000: loss 28.686770
# iteration 10600 / 20000: loss 28.823211
# iteration 10700 / 20000: loss 28.799110
# iteration 10800 / 20000: loss 28.788867
# iteration 10900 / 20000: loss 28.740909
# iteration 11000 / 20000: loss 28.883048
# iteration 11100 / 20000: loss 28.584018
# iteration 11200 / 20000: loss 28.757086
# iteration 11300 / 20000: loss 28.788718
# iteration 11400 / 20000: loss 28.559511
# iteration 11500 / 20000: loss 28.729485
# iteration 11600 / 20000: loss 28.818585
# iteration 11700 / 20000: loss 28.793374
# iteration 11800 / 20000: loss 28.634275
# iteration 11900 / 20000: loss 28.630031
# iteration 12000 / 20000: loss 28.895101
# iteration 12100 / 20000: loss 28.607676
# iteration 12200 / 20000: loss 28.753472
# iteration 12300 / 20000: loss 28.554466
# iteration 12400 / 20000: loss 28.729744
# iteration 12500 / 20000: loss 28.729686
# iteration 12600 / 20000: loss 28.706669
# iteration 12700 / 20000: loss 28.718053
# iteration 12800 / 20000: loss 28.805058
# iteration 12900 / 20000: loss 28.745900
# iteration 13000 / 20000: loss 28.722455
# iteration 13100 / 20000: loss 28.766913
# iteration 13200 / 20000: loss 28.736406
# iteration 13300 / 20000: loss 28.818385
# iteration 13400 / 20000: loss 28.869592
# iteration 13500 / 20000: loss 28.756356
# iteration 13600 / 20000: loss 28.817295
# iteration 13700 / 20000: loss 28.781712
# iteration 13800 / 20000: loss 28.758924
# iteration 13900 / 20000: loss 28.746205
# iteration 14000 / 20000: loss 28.632069
# iteration 14100 / 20000: loss 28.531666
# iteration 14200 / 20000: loss 28.767787
# iteration 14300 / 20000: loss 28.746899
# iteration 14400 / 20000: loss 28.853836
# iteration 14500 / 20000: loss 28.745645
# iteration 14600 / 20000: loss 28.702012
# iteration 14700 / 20000: loss 28.784194
# iteration 14800 / 20000: loss 28.676748
# iteration 14900 / 20000: loss 28.703084
# iteration 15000 / 20000: loss 28.628010
# iteration 15100 / 20000: loss 28.688495
# iteration 15200 / 20000: loss 28.818613
# iteration 15300 / 20000: loss 28.828470
# iteration 15400 / 20000: loss 28.745399
# iteration 15500 / 20000: loss 28.662615
# iteration 15600 / 20000: loss 28.628807
# iteration 15700 / 20000: loss 28.710564
# iteration 15800 / 20000: loss 28.593548
# iteration 15900 / 20000: loss 28.771918
# iteration 16000 / 20000: loss 28.790345
# iteration 16100 / 20000: loss 28.582655
# iteration 16200 / 20000: loss 28.748911
# iteration 16300 / 20000: loss 28.771669
# iteration 16400 / 20000: loss 28.695959
# iteration 16500 / 20000: loss 28.776843
# iteration 16600 / 20000: loss 28.647944
# iteration 16700 / 20000: loss 28.785243
# iteration 16800 / 20000: loss 28.735925
# iteration 16900 / 20000: loss 28.859732
# iteration 17000 / 20000: loss 28.780437
# iteration 17100 / 20000: loss 28.725634
# iteration 17200 / 20000: loss 28.786385
# iteration 17300 / 20000: loss 28.817983
# iteration 17400 / 20000: loss 28.757067
# iteration 17500 / 20000: loss 28.701922
# iteration 17600 / 20000: loss 28.776153
# iteration 17700 / 20000: loss 28.860314
# iteration 17800 / 20000: loss 28.865197
# iteration 17900 / 20000: loss 28.820261
# iteration 18000 / 20000: loss 28.755684
# iteration 18100 / 20000: loss 28.681037
# iteration 18200 / 20000: loss 28.920172
# iteration 18300 / 20000: loss 28.580703
# iteration 18400 / 20000: loss 28.614753
# iteration 18500 / 20000: loss 28.707759
# iteration 18600 / 20000: loss 28.863926
# iteration 18700 / 20000: loss 28.680656
# iteration 18800 / 20000: loss 28.855079
# iteration 18900 / 20000: loss 28.613961
# iteration 19000 / 20000: loss 28.743464
# iteration 19100 / 20000: loss 28.658619
# iteration 19200 / 20000: loss 28.734552
# iteration 19300 / 20000: loss 28.780664
# iteration 19400 / 20000: loss 28.576227
# iteration 19500 / 20000: loss 28.657204
# iteration 19600 / 20000: loss 28.792663
# iteration 19700 / 20000: loss 28.742638
# iteration 19800 / 20000: loss 28.769780
# iteration 19900 / 20000: loss 28.734006
# Validation accuracy:  0.547 Learning rate 0.0005 regularization 1.0
# iteration 0 / 20000: loss 2.303411
# iteration 100 / 20000: loss 2.308674
# iteration 200 / 20000: loss 2.923404
# iteration 300 / 20000: loss 7.410262
# iteration 400 / 20000: loss 12.413557
# iteration 500 / 20000: loss 17.424137
# iteration 600 / 20000: loss 21.460969
# iteration 700 / 20000: loss 24.806128
# iteration 800 / 20000: loss 27.232108
# iteration 900 / 20000: loss 29.516931
# iteration 1000 / 20000: loss 32.095287
# iteration 1100 / 20000: loss 33.751586
# iteration 1200 / 20000: loss 36.024170
# iteration 1300 / 20000: loss 38.022667
# iteration 1400 / 20000: loss 39.690374
# iteration 1500 / 20000: loss 41.653297
# iteration 1600 / 20000: loss 43.404998
# iteration 1700 / 20000: loss 45.294608
# iteration 1800 / 20000: loss 47.008055
# iteration 1900 / 20000: loss 48.614410
# iteration 2000 / 20000: loss 50.324403
# iteration 2100 / 20000: loss 51.753912
# iteration 2200 / 20000: loss 53.373984
# iteration 2300 / 20000: loss 55.083970
# iteration 2400 / 20000: loss 56.587836
# iteration 2500 / 20000: loss 58.325986
# iteration 2600 / 20000: loss 59.577083
# iteration 2700 / 20000: loss 61.125820
# iteration 2800 / 20000: loss 62.485225
# iteration 2900 / 20000: loss 63.896612
# iteration 3000 / 20000: loss 65.105862
# iteration 3100 / 20000: loss 66.208628
# iteration 3200 / 20000: loss 67.323032
# iteration 3300 / 20000: loss 68.452496
# iteration 3400 / 20000: loss 69.389447
# iteration 3500 / 20000: loss 70.467300
# iteration 3600 / 20000: loss 71.626133
# iteration 3700 / 20000: loss 72.526515
# iteration 3800 / 20000: loss 73.310045
# iteration 3900 / 20000: loss 74.091508
# iteration 4000 / 20000: loss 74.865239
# iteration 4100 / 20000: loss 75.609147
# iteration 4200 / 20000: loss 76.375417
# iteration 4300 / 20000: loss 77.050428
# iteration 4400 / 20000: loss 77.559223
# iteration 4500 / 20000: loss 78.383934
# iteration 4600 / 20000: loss 78.906218
# iteration 4700 / 20000: loss 79.333613
# iteration 4800 / 20000: loss 79.898127
# iteration 4900 / 20000: loss 80.473705
# iteration 5000 / 20000: loss 80.735715
# iteration 5100 / 20000: loss 81.117132
# iteration 5200 / 20000: loss 81.548391
# iteration 5300 / 20000: loss 81.855254
# iteration 5400 / 20000: loss 82.377586
# iteration 5500 / 20000: loss 82.494826
# iteration 5600 / 20000: loss 82.907252
# iteration 5700 / 20000: loss 83.024180
# iteration 5800 / 20000: loss 83.373608
# iteration 5900 / 20000: loss 83.849593
# iteration 6000 / 20000: loss 83.935673
# iteration 6100 / 20000: loss 84.129354
# iteration 6200 / 20000: loss 84.331427
# iteration 6300 / 20000: loss 84.484338
# iteration 6400 / 20000: loss 84.751288
# iteration 6500 / 20000: loss 84.972051
# iteration 6600 / 20000: loss 85.032353
# iteration 6700 / 20000: loss 85.375151
# iteration 6800 / 20000: loss 85.511484
# iteration 6900 / 20000: loss 85.609290
# iteration 7000 / 20000: loss 85.547837
# iteration 7100 / 20000: loss 85.747710
# iteration 7200 / 20000: loss 85.877907
# iteration 7300 / 20000: loss 86.159668
# iteration 7400 / 20000: loss 85.972778
# iteration 7500 / 20000: loss 86.201717
# iteration 7600 / 20000: loss 86.314583
# iteration 7700 / 20000: loss 86.381519
# iteration 7800 / 20000: loss 86.416348
# iteration 7900 / 20000: loss 86.505926
# iteration 8000 / 20000: loss 86.688702
# iteration 8100 / 20000: loss 86.656674
# iteration 8200 / 20000: loss 86.828226
# iteration 8300 / 20000: loss 86.769358
# iteration 8400 / 20000: loss 86.841604
# iteration 8500 / 20000: loss 86.818355
# iteration 8600 / 20000: loss 86.721071
# iteration 8700 / 20000: loss 86.804091
# iteration 8800 / 20000: loss 86.961006
# iteration 8900 / 20000: loss 87.119271
# iteration 9000 / 20000: loss 87.021113
# iteration 9100 / 20000: loss 86.973412
# iteration 9200 / 20000: loss 87.126082
# iteration 9300 / 20000: loss 87.222029
# iteration 9400 / 20000: loss 87.133198
# iteration 9500 / 20000: loss 87.066997
# iteration 9600 / 20000: loss 87.159567
# iteration 9700 / 20000: loss 87.255636
# iteration 9800 / 20000: loss 87.200236
# iteration 9900 / 20000: loss 87.219020
# iteration 10000 / 20000: loss 87.191621
# iteration 10100 / 20000: loss 87.208836
# iteration 10200 / 20000: loss 87.299690
# iteration 10300 / 20000: loss 87.280642
# iteration 10400 / 20000: loss 87.466877
# iteration 10500 / 20000: loss 87.380844
# iteration 10600 / 20000: loss 87.241301
# iteration 10700 / 20000: loss 87.419864
# iteration 10800 / 20000: loss 87.355154
# iteration 10900 / 20000: loss 87.266597
# iteration 11000 / 20000: loss 87.507800
# iteration 11100 / 20000: loss 87.272661
# iteration 11200 / 20000: loss 87.326328
# iteration 11300 / 20000: loss 87.328670
# iteration 11400 / 20000: loss 87.273846
# iteration 11500 / 20000: loss 87.350356
# iteration 11600 / 20000: loss 87.267439
# iteration 11700 / 20000: loss 87.507359
# iteration 11800 / 20000: loss 87.321554
# iteration 11900 / 20000: loss 87.499206
# iteration 12000 / 20000: loss 87.379484
# iteration 12100 / 20000: loss 87.342291
# iteration 12200 / 20000: loss 87.409170
# iteration 12300 / 20000: loss 87.380567
# iteration 12400 / 20000: loss 87.320173
# iteration 12500 / 20000: loss 87.496433
# iteration 12600 / 20000: loss 87.632628
# iteration 12700 / 20000: loss 87.407392
# iteration 12800 / 20000: loss 87.319209
# iteration 12900 / 20000: loss 87.516956
# iteration 13000 / 20000: loss 87.389483
# iteration 13100 / 20000: loss 87.638192
# iteration 13200 / 20000: loss 87.496700
# iteration 13300 / 20000: loss 87.264858
# iteration 13400 / 20000: loss 87.431851
# iteration 13500 / 20000: loss 87.507521
# iteration 13600 / 20000: loss 87.389768
# iteration 13700 / 20000: loss 87.554523
# iteration 13800 / 20000: loss 87.542033
# iteration 13900 / 20000: loss 87.491626
# iteration 14000 / 20000: loss 87.513081
# iteration 14100 / 20000: loss 87.386956
# iteration 14200 / 20000: loss 87.468248
# iteration 14300 / 20000: loss 87.434574
# iteration 14400 / 20000: loss 87.659776
# iteration 14500 / 20000: loss 87.524032
# iteration 14600 / 20000: loss 87.504186
# iteration 14700 / 20000: loss 87.623383
# iteration 14800 / 20000: loss 87.473245
# iteration 14900 / 20000: loss 87.552320
# iteration 15000 / 20000: loss 87.657037
# iteration 15100 / 20000: loss 87.426125
# iteration 15200 / 20000: loss 87.500856
# iteration 15300 / 20000: loss 87.540731
# iteration 15400 / 20000: loss 87.404137
# iteration 15500 / 20000: loss 87.601550
# iteration 15600 / 20000: loss 87.454035
# iteration 15700 / 20000: loss 87.615714
# iteration 15800 / 20000: loss 87.530981
# iteration 15900 / 20000: loss 87.404335
# iteration 16000 / 20000: loss 87.369816
# iteration 16100 / 20000: loss 87.555884
# iteration 16200 / 20000: loss 87.501793
# iteration 16300 / 20000: loss 87.416797
# iteration 16400 / 20000: loss 87.478809
# iteration 16500 / 20000: loss 87.623733
# iteration 16600 / 20000: loss 87.517888
# iteration 16700 / 20000: loss 87.457058
# iteration 16800 / 20000: loss 87.415624
# iteration 16900 / 20000: loss 87.568211
# iteration 17000 / 20000: loss 87.549040
# iteration 17100 / 20000: loss 87.523407
# iteration 17200 / 20000: loss 87.572671
# iteration 17300 / 20000: loss 87.438652
# iteration 17400 / 20000: loss 87.491224
# iteration 17500 / 20000: loss 87.591728
# iteration 17600 / 20000: loss 87.508952
# iteration 17700 / 20000: loss 87.479927
# iteration 17800 / 20000: loss 87.511166
# iteration 17900 / 20000: loss 87.488037
# iteration 18000 / 20000: loss 87.620524
# iteration 18100 / 20000: loss 87.578684
# iteration 18200 / 20000: loss 87.550460
# iteration 18300 / 20000: loss 87.465776
# iteration 18400 / 20000: loss 87.396033
# iteration 18500 / 20000: loss 87.638298
# iteration 18600 / 20000: loss 87.472629
# iteration 18700 / 20000: loss 87.415641
# iteration 18800 / 20000: loss 87.570590
# iteration 18900 / 20000: loss 87.311662
# iteration 19000 / 20000: loss 87.487497
# iteration 19100 / 20000: loss 87.558468
# iteration 19200 / 20000: loss 87.441126
# iteration 19300 / 20000: loss 87.447643
# iteration 19400 / 20000: loss 87.596885
# iteration 19500 / 20000: loss 87.504559
# iteration 19600 / 20000: loss 87.445451
# iteration 19700 / 20000: loss 87.454113
# iteration 19800 / 20000: loss 87.491575
# iteration 19900 / 20000: loss 87.671750
# Validation accuracy:  0.544 Learning rate 0.0005 regularization 2.0
# iteration 0 / 20000: loss 2.306673
# iteration 100 / 20000: loss 2.342644
# iteration 200 / 20000: loss 10.526356
# iteration 300 / 20000: loss 51.244178
# iteration 400 / 20000: loss 109.607345
# iteration 500 / 20000: loss 187.244025
# iteration 600 / 20000: loss 278.688199
# iteration 700 / 20000: loss 414.265075
# iteration 800 / 20000: loss 607.883520
# iteration 900 / 20000: loss 894.593739
# iteration 1000 / 20000: loss 1334.012721
# iteration 1100 / 20000: loss 1920.514300
# iteration 1200 / 20000: loss 2803.850168
# iteration 1300 / 20000: loss 3968.682090
# iteration 1400 / 20000: loss 5560.446882
# iteration 1500 / 20000: loss 7730.467893
# iteration 1600 / 20000: loss 10391.653075
# iteration 1700 / 20000: loss 14018.033736
# iteration 1800 / 20000: loss 18246.013587
# iteration 1900 / 20000: loss 23611.175529
# iteration 2000 / 20000: loss 30134.358656
# iteration 2100 / 20000: loss 37599.007583
# iteration 2200 / 20000: loss 46943.154213
# iteration 2300 / 20000: loss 56837.178126
# iteration 2400 / 20000: loss 68724.830229
# iteration 2500 / 20000: loss 81985.324573
# iteration 2600 / 20000: loss 96393.432666
# iteration 2700 / 20000: loss 113280.590052
# iteration 2800 / 20000: loss 130047.806661
# iteration 2900 / 20000: loss 149335.719704
# iteration 3000 / 20000: loss 169429.343643
# iteration 3100 / 20000: loss 190630.960187
# iteration 3200 / 20000: loss 213963.089862
# iteration 3300 / 20000: loss inf
# iteration 3400 / 20000: loss inf
# iteration 3500 / 20000: loss 286104.234314
# iteration 3600 / 20000: loss 311619.416551
# iteration 3700 / 20000: loss 338389.858961
# iteration 3800 / 20000: loss inf
# iteration 3900 / 20000: loss inf
# iteration 4000 / 20000: loss 417283.626016
# iteration 4100 / 20000: loss inf
# iteration 4200 / 20000: loss 470781.097197
# iteration 4300 / 20000: loss inf
# iteration 4400 / 20000: loss inf
# iteration 4500 / 20000: loss inf
# iteration 4600 / 20000: loss inf
# iteration 4700 / 20000: loss inf
# iteration 4800 / 20000: loss inf
# iteration 4900 / 20000: loss inf
# iteration 5000 / 20000: loss inf
# iteration 5100 / 20000: loss inf
# iteration 5200 / 20000: loss inf
# iteration 5300 / 20000: loss inf
# iteration 5400 / 20000: loss inf
# iteration 5500 / 20000: loss inf
# iteration 5600 / 20000: loss inf
# iteration 5700 / 20000: loss inf
# iteration 5800 / 20000: loss inf
# iteration 5900 / 20000: loss inf
# iteration 6000 / 20000: loss inf
# iteration 6100 / 20000: loss inf
# iteration 6200 / 20000: loss inf
# iteration 6300 / 20000: loss inf
# iteration 6400 / 20000: loss inf
# iteration 6500 / 20000: loss inf
# iteration 6600 / 20000: loss inf
# iteration 6700 / 20000: loss inf
# iteration 6800 / 20000: loss inf
# iteration 6900 / 20000: loss inf
# iteration 7000 / 20000: loss inf
# iteration 7100 / 20000: loss inf
# iteration 7200 / 20000: loss inf
# iteration 7300 / 20000: loss inf
# iteration 7400 / 20000: loss inf
# iteration 7500 / 20000: loss inf
# iteration 7600 / 20000: loss inf
# iteration 7700 / 20000: loss inf
# iteration 7800 / 20000: loss inf
# iteration 7900 / 20000: loss inf
# iteration 8000 / 20000: loss inf
# iteration 8100 / 20000: loss inf
# iteration 8200 / 20000: loss inf
# iteration 8300 / 20000: loss inf
# iteration 8400 / 20000: loss inf
# iteration 8500 / 20000: loss inf
# iteration 8600 / 20000: loss inf
# iteration 8700 / 20000: loss inf
# iteration 8800 / 20000: loss inf
# iteration 8900 / 20000: loss inf
# iteration 9000 / 20000: loss inf
# iteration 9100 / 20000: loss inf
# iteration 9200 / 20000: loss inf
# iteration 9300 / 20000: loss inf
# iteration 9400 / 20000: loss inf
# iteration 9500 / 20000: loss inf
# iteration 9600 / 20000: loss inf
# iteration 9700 / 20000: loss inf
# iteration 9800 / 20000: loss inf
# iteration 9900 / 20000: loss inf
# iteration 10000 / 20000: loss inf
# iteration 10100 / 20000: loss inf
# iteration 10200 / 20000: loss inf
# iteration 10300 / 20000: loss inf
# iteration 10400 / 20000: loss inf
# iteration 10500 / 20000: loss inf
# iteration 10600 / 20000: loss inf
# iteration 10700 / 20000: loss inf
# iteration 10800 / 20000: loss inf
# iteration 10900 / 20000: loss inf
# iteration 11000 / 20000: loss inf
# iteration 11100 / 20000: loss inf
# iteration 11200 / 20000: loss inf
# iteration 11300 / 20000: loss inf
# iteration 11400 / 20000: loss inf
# iteration 11500 / 20000: loss inf
# iteration 11600 / 20000: loss inf
# iteration 11700 / 20000: loss inf
# iteration 11800 / 20000: loss inf
# iteration 11900 / 20000: loss inf
# iteration 12000 / 20000: loss inf
# iteration 12100 / 20000: loss inf
# iteration 12200 / 20000: loss inf
# iteration 12300 / 20000: loss inf
# iteration 12400 / 20000: loss inf
# iteration 12500 / 20000: loss inf
# iteration 12600 / 20000: loss inf
# iteration 12700 / 20000: loss inf
# iteration 12800 / 20000: loss inf
# iteration 12900 / 20000: loss inf
# iteration 13000 / 20000: loss inf
# iteration 13100 / 20000: loss inf
# iteration 13200 / 20000: loss inf
# iteration 13300 / 20000: loss inf
# iteration 13400 / 20000: loss inf
# iteration 13500 / 20000: loss inf
# iteration 13600 / 20000: loss inf
# iteration 13700 / 20000: loss inf
# iteration 13800 / 20000: loss inf
# iteration 13900 / 20000: loss inf
# iteration 14000 / 20000: loss inf
# iteration 14100 / 20000: loss inf
# iteration 14200 / 20000: loss inf
# iteration 14300 / 20000: loss inf
# iteration 14400 / 20000: loss inf
# iteration 14500 / 20000: loss inf
# iteration 14600 / 20000: loss inf
# iteration 14700 / 20000: loss inf
# iteration 14800 / 20000: loss inf
# iteration 14900 / 20000: loss inf
# iteration 15000 / 20000: loss inf
# iteration 15100 / 20000: loss inf
# iteration 15200 / 20000: loss inf
# iteration 15300 / 20000: loss inf
# iteration 15400 / 20000: loss inf
# iteration 15500 / 20000: loss inf
# iteration 15600 / 20000: loss inf
# iteration 15700 / 20000: loss inf
# iteration 15800 / 20000: loss inf
# iteration 15900 / 20000: loss inf
# iteration 16000 / 20000: loss inf
# iteration 16100 / 20000: loss inf
# iteration 16200 / 20000: loss inf
# iteration 16300 / 20000: loss inf
# iteration 16400 / 20000: loss inf
# iteration 16500 / 20000: loss inf
# iteration 16600 / 20000: loss inf
# iteration 16700 / 20000: loss inf
# iteration 16800 / 20000: loss inf
# iteration 16900 / 20000: loss inf
# iteration 17000 / 20000: loss inf
# iteration 17100 / 20000: loss 1093828.160120
# iteration 17200 / 20000: loss inf
# iteration 17300 / 20000: loss inf
# iteration 17400 / 20000: loss inf
# iteration 17500 / 20000: loss 1093873.494323
# iteration 17600 / 20000: loss inf
# iteration 17700 / 20000: loss inf
# iteration 17800 / 20000: loss inf
# iteration 17900 / 20000: loss inf
# iteration 18000 / 20000: loss inf
# iteration 18100 / 20000: loss inf
# iteration 18200 / 20000: loss inf
# iteration 18300 / 20000: loss inf
# iteration 18400 / 20000: loss inf
# iteration 18500 / 20000: loss inf
# iteration 18600 / 20000: loss inf
# iteration 18700 / 20000: loss inf
# iteration 18800 / 20000: loss inf
# iteration 18900 / 20000: loss inf
# iteration 19000 / 20000: loss inf
# iteration 19100 / 20000: loss inf
# iteration 19200 / 20000: loss inf
# iteration 19300 / 20000: loss inf
# iteration 19400 / 20000: loss inf
# iteration 19500 / 20000: loss inf
# iteration 19600 / 20000: loss inf
# iteration 19700 / 20000: loss inf
# iteration 19800 / 20000: loss inf
# iteration 19900 / 20000: loss inf
# Validation accuracy:  0.47 Learning rate 0.0005 regularization 10.0
# lr 5.000000e-09 reg 1.000000e+05 train accuracy: 0.244592 val accuracy: 0.239000
# lr 8.000000e-01 reg 5.000000e-04 train accuracy: 0.560000 val accuracy: 0.533000
# lr 1.000000e+00 reg 5.000000e-04 train accuracy: 0.564878 val accuracy: 0.547000
# lr 2.000000e+00 reg 5.000000e-04 train accuracy: 0.576000 val accuracy: 0.544000
# lr 1.000000e+01 reg 2.000000e-04 train accuracy: 0.516776 val accuracy: 0.501000
# lr 1.000000e+01 reg 5.000000e-04 train accuracy: 0.563551 val accuracy: 0.470000
# best validation accuracy achieved during cross-validation: 0.552000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.473

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
